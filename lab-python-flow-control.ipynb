# %% [markdown]
# # Lab | Flow Control

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized
#
# In the last lab, you were starting an online store that sells various products. To ensure smooth operations, you developed a program that manages customer orders and inventory.
#
# You did so without using flow control. Let's go a step further and improve this code.
#
# Follow the steps below to complete the exercise:
#
# 1. Look at your code from the lab data structures, and improve repeated code with loops.
#
# 2. Instead of asking the user to input the name of three products that a customer wants to order, do the following:
#
#     a. Prompt the user to enter the name of a product that a customer wants to order.
#
#     b. Add the product name to the "customer_orders" set.
#
#     c. Ask the user if they want to add another product (yes/no).
#
#     d. Continue the loop until the user does not want to add another product.
#
# 3. Instead of updating the inventory by subtracting 1 from the quantity of each product, only do it for  the products that were ordered (those in "customer_orders").

# %%
# Step 1: list of products 
products = ["t-shirt", "mug", "hat", "book", "keychain"]

# Step 2: create an empty dictionary 
inventory = {}

# Step 3: ask the user for each product quantity and add it to the dictionary
print("____Inventory Setup ____")
for product in products:
    inventory[product] = int(input(f"Enter quantity for {product}: "))

# Step 4: Create an empty set for customer orders
customer_orders = set()

# Step 5: Ask user for orders dynamically using a loop with a yes/no prompt
print("\n___ Place Customer Order ___")
while True:
    # a. Prompt the user to enter the name of a product
    ordered_item = input("Enter the name of a product to order: ").strip().lower()
    
    # b. Add the product name to the "customer_orders" set
    customer_orders.add(ordered_item)
    
    # c. Ask the user if they want to add another product (yes/no)
    another = input("Do you want to add another product? (yes/no): ").strip().lower()
    
    # d. Continue the loop until the user does not want to add another product
    if another != 'yes':
        break

# Step 6: Print the products in the customer_orders set
print("\nProducts ordered:")
print(customer_orders)

# Step 7: Calculate order statistics and store them in a tuple
total_products_ordered = len(customer_orders)
percentage_ordered = (total_products_ordered / len(products)) * 100
order_status = (total_products_ordered, percentage_ordered)

# Step 8: Print the order statistics using f-strings
print("\nOrder Statistics:")
print(f"Total Products Ordered: {order_status[0]}")
print(f"Percentage of Products Ordered: {order_status[1]:.1f}%")

# Step 9: Update the inventory ONLY for the products that were ordered
for product in customer_orders:
    if product in inventory:
        inventory[product] -= 1

# Step 10: Print the updated inventory on separate lines using a loop
print("\nUpdated Inventory:")
for product in products:
    print(f"{product}: {inventory[product]}")
# Out:
# ____Inventory Setup ____
# Enter quantity for t-shirt:  2
# Enter quantity for mug:  2
# Enter quantity for hat:  2
# Enter quantity for book:  2
# Enter quantity for keychain:  2
# ___ Place Customer Order ___
# Enter the name of a product to order:  hat
# Do you want to add another product? (yes/no):  no
# Products ordered:
# {'hat'}
#
# Order Statistics:
# Total Products Ordered: 1
# Percentage of Products Ordered: 20.0%
#
# Updated Inventory:
# t-shirt: 2
# mug: 2
# hat: 1
# book: 2
# keychain: 2
